# %%
! pip3 install -e ../sdk/python
# Out:
# Obtaining file:///Users/bdgv224/Development/SynergyPlus/sdk/python
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.31 in /Users/bdgv224/Development/SynergyPlus/.venv/lib/python3.14/site-packages (from synergyplus==0.2.0) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/bdgv224/Development/SynergyPlus/.venv/lib/python3.14/site-packages (from requests>=2.31->synergyplus==0.2.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bdgv224/Development/SynergyPlus/.venv/lib/python3.14/site-packages (from requests>=2.31->synergyplus==0.2.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/bdgv224/Development/SynergyPlus/.venv/lib/python3.14/site-packages (from requests>=2.31->synergyplus==0.2.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/bdgv224/Development/SynergyPlus/.venv/lib/python3.14/site-packages (from requests>=2.31->synergyplus==0.2.0) (2026.6.17)
# Building wheels for collected packages: synergyplus
#   Building editable for synergyplus (pyproject.toml) ... done
#   Created wheel for synergyplus: filename=synergyplus-0.2.0-0.editable-py3-none-any.whl size=2844 sha256=7d4d79e084bab38eac9085e3fff3c6389a347b6219855816737f1d1e0a5a7515
#   Stored in directory: /private/var/folders/6q/y15s9hpn2qd88j9vv8gjhkn80000gq/T/pip-ephem-wheel-cache-tg4drpek/wheels/fe/5e/f3/ad320999d46d07166e85dc796172530dc8c89abc3aa004561d
# Successfully built synergyplus
# Installing collected packages: synergyplus
#   Attempting uninstall: synergyplus
#     Found existing installation: synergyplus 0.2.0
#     Uninstalling synergyplus-0.2.0:
#       Successfully uninstalled synergyplus-0.2.0
# Successfully installed synergyplus-0.2.0

# %%
from synergyplus import SynergyClient, ArtifactRef
sp = SynergyClient("http://localhost:8090", token="sp_live_3b2d7e1569632714390932ee6c42bfd9a20c145718b70bbb")
sim = sp.submit_simulation(
    engine_version="24.1.0",
    model=ArtifactRef("s3://models/sample/baseline.idf"),
    weather=ArtifactRef("s3://weather/sample/chicago.epw"),
)

print("submitted", sim["id"])
print("final", sp.wait(sim["id"]))
print("results", sp.get_results(sim["id"]))
# Out:
# submitted 931a49bb-b505-437e-9938-fccf671d2ba9
# final {'id': '931a49bb-b505-437e-9938-fccf671d2ba9', 'result': {'artifactUri': 's3://results/ebeee2ff7c95d4d3fb772958d7f9b58b0fe555893572cd4ec0862350f1905208/', 'metrics': {'run_seconds': 1.005, 'site_eui': 179.3, 'source_eui': 507.42, 'total_site_energy': 266.08, 'total_source_energy': 753.01, 'unmet_cooling_hours': 4, 'unmet_heating_hours': 43}, 'verdict': 'clean'}, 'state': 'succeeded', 'verdict': 'clean'}
# results {'artifactUri': 's3://results/ebeee2ff7c95d4d3fb772958d7f9b58b0fe555893572cd4ec0862350f1905208/', 'metrics': {'run_seconds': 1.005, 'site_eui': 179.3, 'source_eui': 507.42, 'total_site_energy': 266.08, 'total_source_energy': 753.01, 'unmet_cooling_hours': 4, 'unmet_heating_hours': 43}, 'verdict': 'clean'}
